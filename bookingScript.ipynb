# %%
from sqlalchemy import create_engine
# %load_ext sql
# %sql postgresql://postgres:polpol@localhost:5430/postgres

#Booking a ticket
welcome = input("Do you have an account? y/n: ")
if welcome == "n":
    while True:
        username  = input("Enter a username:")
        password  = input("Enter a password:")
        password1 = input("Confirm password:")
        if password == password1:
            #file = open(username+".txt", "w")
            # %sql Insert INTO user_info(username1,password1) values('{username}','{password}') 
            #file.write(username+":"+password)
           # file.close()
            welcome = "y"
            break
        print("Passwords do NOT match!")
 
if welcome == "y":
    while True:
        login1 = input("Login username:")
        login2 = input("Enter Password:")
        
        data = %sql SELECT username1 from user_info WHERE (username1= '{login1}')
        p = list(data[0])
        p[0]

        if p [0]== login1:
            print("HELLO!! SAWBONA!! THOBELA!! RO VHATANGANEDZA\n")
            print("WELCOME TO MOVIE BOOKING!!!!!\n")
            break
        print("Incorrect username or password.")
        break
#CHOOSING A MOVIE

def select_Movie():

    print("Which movie do you want to watch : \n")

    selection = int(input("choose your movie between 0,1,2,3,4,5: "))
    movies =["Spider Man, R68", "sing_2, R90", "karate Kid, 78", "scream, R68","Me before You, R95", "Night School, R78"]

    #Input the date for your movie

    selection = int(input("Choose available dates: 0: 17 Jan,\n 1: 18 Jan ,\n 2: 19 Jan ,\n 3: 20 Jan,\n 4: 21 Jan,\n 5: 22 Jan,\n 6: 23 Jan,\n 7:24 Jan,\n 8: 25 Jan,\n 9: 26 Jan,\n 10: 27 Jan,\n 11: 28 Jan,\n 12: 29 Jan,\n 13: 30 Jan" ))
    date = ["17 Jan","18 Jan", "19 Jan","20 Jan", "21 Jan", "22 Jan","23 Jan","24 Jan", "25 Jan", "26 Jan","27 Jan","28 Jan","29 Jan","30 Jan",]

    #Input the time for your movie
    selection = int(input("choose your time between 0,1,2,3,4,5: "))
    time1 = ["10.00-1.00", "1.10-4.10", "4.20-7.20", "7.30-10.30", "10.15-1.15",  "1.25-4.25"]
     #Inserting the selected values in a table

    # %sql Insert INTO movie(title,date,time) values('{movies[selection]}','{date[selection]}','{time1[selection]}')
    movie_choice = movies[selection] 
    print(movies[selection])

    movie_date = date[selection]
    print(date[selection])

    movie_time = time1[selection]
    print(time1[selection])
select_Movie()

#CHOOSING A CINEMA 

def select_Cinema():

    print("which cinema do you want to watch your movie at : \n")

    selection = int(input("choose your cinema between: 0: Sterland,pretoria',\n 1: Brooklyn,pretoria',\n 2: Kollonade,pretoria,\n 3: The zone rosebank,johannesburg,\n 4: cresta,johannesburg ,\n 5: centurion,pretoria,\n 6: sandton,johanneburg: "))
    cinema1 = ['Sterland,pretoria','Brooklyn,pretoria','Kollonade,pretoria','The zone rosebank,johannesburg','cresta,johannesburg','centurion,pretoria','sandton,johanneburg', ]
   

    # %sql Insert INTO cinema(cinemas) values('{cinema1[selection]}')
    cinema_choice = cinema1[selection] 
    print(cinema1[selection])

select_Cinema()
#TOTAL PRICE



#SELECT EXTRAS

def select_Extras():

    print(" \n")

    selection = int(input("choose your extras, 1:Combo1\n 2:Combo2\n 3:Combo3 "))
    combo1 = ["Pop corn", "smaties", "Pepsi", "2D"]
    combo2 = ["Simba ","easteregg", "Orange Juice", "2D"]
    combo3 = ["Doritoz ","chocolate ","slushious ","3D "]

    if selection == 1:
        print("you have selected a combo ")
        print(combo1)
    elif selection==2:
        print("you have selected a combo ")
        print(combo2) 
    elif selection==3:
        print("you have selected a combo ")
        print(combo3)
    else:
        print("you did not select any combo,proceed to the next step")

select_Extras()

#TOTAL PRICE
global total_price
user_input = input("Enter movie name available Spider_Man. \n Sing2 \n Karate Kid. \n Scream. \n Me before You. \n Night School: ")
user_input = user_input.split(',')
my_dictionary={"Spider_Man":68,"Sing2":90, "Karate Kid":78, "Scream":68 , "Me Before You":95, "Night School":78 }
total_price = 0

for items in user_input:
    try:
        total_price = total_price + my_dictionary[items]
    except:
        total_price = "Some movies are not avaiable in our system."
        break
    total_price= total_price + 70
print("TOTAL PRICE IS: " + str(total_price))


#Generating a Seat Number
import random as rand
def selecting_seats():
    seat_number=rand.sample(range(1, 50), 1)
    print("Your Seat number is " + str(seat_number))

selecting_seats()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#  * postgresql://postgres:***@localhost:5430/postgres
# 1 rows affected.
# HELLO!! SAWBONA!! THOBELA!! RO VHATANGANEDZA
#
# WELCOM TO MOVIE BOOKING!!!!!
#
# Which movie do you want to watch :
#
#  * postgresql://postgres:***@localhost:5430/postgres
# 1 rows affected.
# Night School, R78
# 22 Jan
# 1.25-4.25
# which cinema do you want to watch your movie at :
#
#  * postgresql://postgres:***@localhost:5430/postgres
# 1 rows affected.
# sandton,johanneburg
#
#
# you have selected a combo
# ['Doritoz ', 'chocolate ', 'slushious ', '3D ']
# TOTAL PRICE IS: 138
# Your Seat number is [49]
